# %% [markdown]
# $\text{Excercise F}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from Formulas import f

# %%
S = 511
mass = 700 *1000#klb
mass = f.lb__kg(mass,1)
CL_M = 1.16
dCL_alpha = 0.1
dCL_alpha = 0.1*180/np.pi
V = f.Mach_To_V_Calc(0.8,228.71)
#1
U_de = 18 #m/s from graph in course Note
W_S = mass*9.81/S
print(W_S)
P,T,rho = f.get_atmosphere_properties(0,)
P_30,T_30,rho_30= f.get_atmosphere_properties(30000,'ft')



print(K)
Veq = f.EAS(V,rho_30) #
print(Veq)
# Out:
# 6095.53582150685
# 0.7327560278683176
# 148.3509114793546
# 2.126727682366703

# %% [markdown]
# Calculate the ’statistical gust alleviation factor’ (K) for the given aircraft.

# %%
K = 0.8 - 5.25/(W_S**(1/2))

# %% [markdown]
# 3) In turbulence, calculate the (rough air) gust load for the given flight conditions.

# %%
Veq = f.EAS(V,rho_30) #

n = 1 +K*dCL_alpha*((rho*Veq*U_de)/(2*W_S))
print(n)
